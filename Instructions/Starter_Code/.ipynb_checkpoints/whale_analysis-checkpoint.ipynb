# %% [markdown]
#  #  A Whale off the Port(folio)
#  ---
#
#  In this assignment, you'll get to use what you've learned this week to evaluate the performance among various algorithmic, hedge, and mutual fund portfolios and compare them against the S&P TSX 60 Index.

# %%
# Initial imports
import pandas as pd
import numpy as np
import datetime as dt
from pathlib import Path

# %matplotlib inline

# %% [markdown]
# # Data Cleaning
#
# In this section, you will need to read the CSV files into DataFrames and perform any necessary data cleaning steps. After cleaning, combine all DataFrames into a single DataFrame.
#
# Files:
#
# * `whale_returns.csv`: Contains returns of some famous "whale" investors' portfolios.
#
# * `algo_returns.csv`: Contains returns from the in-house trading algorithms from Harold's company.
#
# * `sp_tsx_history.csv`: Contains historical closing prices of the S&P TSX 60 Index.

# %% [markdown]
# ## Whale Returns
#
# Read the Whale Portfolio daily returns and clean the data.

# %%
# Reading whale returns
whale_returns_csv = Path("whale_returns.csv")
whale_returns_df = pd.read_csv(whale_returns_csv)
whale_returns_df['Date'] = pd.to_datetime(whale_returns_df["Date"], dayfirst = True)
whale_returns_df.set_index(whale_returns_df['Date'], inplace=True)
whale_returns_df.drop(columns=['Date'],inplace=True)
whale_returns_df.head()
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-02                        NaN                 NaN
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC
# Date
# 2015-03-02                          NaN                     NaN
# 2015-03-03                    -0.000496               -0.006569
# 2015-03-04                    -0.002534                0.004213
# 2015-03-05                     0.002355                0.006726
# 2015-03-06                    -0.008481               -0.013098

# %%
# Count nulls
#whale_returns_df.isnull().mean() * 100
whale_returns_df.isnull().sum()
# Out:
# SOROS FUND MANAGEMENT LLC      1
# PAULSON & CO.INC.              1
# TIGER GLOBAL MANAGEMENT LLC    1
# BERKSHIRE HATHAWAY INC         1
# dtype: int64

# %%
# Drop nulls
whale_returns_df = whale_returns_df.dropna()

# %%
whale_returns_df.head()
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
# 2015-03-09                   0.000582            0.004225
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC
# Date
# 2015-03-03                    -0.000496               -0.006569
# 2015-03-04                    -0.002534                0.004213
# 2015-03-05                     0.002355                0.006726
# 2015-03-06                    -0.008481               -0.013098
# 2015-03-09                     0.005843               -0.001652

# %% [markdown]
# ## Algorithmic Daily Returns
#
# Read the algorithmic daily returns and clean the data.

# %%
# Reading algorithmic returns
algo_returns_csv = Path("algo_returns.csv")
algo_returns_df = pd.read_csv(algo_returns_csv, index_col="Date", parse_dates=True, infer_datetime_format=True)
algo_returns_df.sort_index(ascending = True, inplace = True)
algo_returns_df.head(100)
# Out:
#               Algo 1    Algo 2
# Date
# 2014-05-28  0.001745       NaN
# 2014-05-29  0.003978       NaN
# 2014-05-30  0.004464       NaN
# 2014-06-02  0.005692       NaN
# 2014-06-03  0.005292       NaN
# ...              ...       ...
# 2014-10-10 -0.012612 -0.011752
# 2014-10-13 -0.018528 -0.002009
# 2014-10-14  0.000702  0.004501
# 2014-10-15  0.021616 -0.000977
# 2014-10-16  0.098246  0.083734
#
# [100 rows x 2 columns]

# %%
# Count nulls
algo_returns_df.isnull().sum()
# Out:
# Algo 1    0
# Algo 2    6
# dtype: int64

# %%
# Drop nulls
algo_returns_df.dropna(inplace = True)
algo_returns_df.head()
# Out:
#               Algo 1    Algo 2
# Date
# 2014-06-05  0.004062  0.013285
# 2014-06-06  0.001857  0.008284
# 2014-06-09 -0.005012  0.005668
# 2014-06-10  0.004406 -0.000735
# 2014-06-11  0.004760 -0.003761

# %% [markdown]
# ## S&P TSX 60 Returns
#
# Read the S&P TSX 60 historic closing prices and create a new daily returns DataFrame from the data.

# %%
# Reading S&P TSX 60 Closing Prices
sp_tsx_history_csv = Path("sp_tsx_history.csv")
sp_tsx_history_df = pd.read_csv(sp_tsx_history_csv)
sp_tsx_history_df['Date'] = pd.to_datetime(sp_tsx_history_df["Date"], dayfirst = True)
sp_tsx_history_df.set_index(sp_tsx_history_df['Date'], inplace=True)
sp_tsx_history_df.drop(columns=['Date'],inplace=True)
sp_tsx_history_df['Close'] = sp_tsx_history_df['Close'].str.replace('$', '')
sp_tsx_history_df['Close']
sp_tsx_history_df = sp_tsx_history_df.sort_values("Date", ascending=True)
sp_tsx_history_df.head(10)
sp_tsx_history_df['Close'] = sp_tsx_history_df['Close'].str.replace(',', '')

# %%
# Check Data Types
sp_tsx_history_df.dtypes
# Out:
# Close    object
# dtype: object

# %%
# Fix Data Types
sp_tsx_history_df["Close"] = sp_tsx_history_df["Close"].astype("float")
sp_tsx_history_df["Close"].dtype
# Out:
# dtype('float64')

# %%
# Calculate Daily Returns
sp_tsx_history_df.isnull().sum()
sp_tsx_returns_df = sp_tsx_history_df.pct_change()
sp_tsx_returns_df.head()
# Out:
#                Close
# Date
# 2012-10-01       NaN
# 2012-10-02  0.001701
# 2012-10-03 -0.002563
# 2012-10-04  0.007137
# 2012-10-05 -0.002305

# %%
# Drop nulls
sp_tsx_returns_df.dropna(inplace=True)
sp_tsx_returns_df.head()
# Out:
#                Close
# Date
# 2012-10-02  0.001701
# 2012-10-03 -0.002563
# 2012-10-04  0.007137
# 2012-10-05 -0.002305
# 2012-10-09 -0.011709

# %%
# Rename `Close` Column to be specific to this portfolio.
sp_tsx_returns_df = sp_tsx_returns_df.rename(columns={"Close":"S&P500"})
sp_tsx_returns_df.head()
# Out:
#               S&P500
# Date
# 2012-10-02  0.001701
# 2012-10-03 -0.002563
# 2012-10-04  0.007137
# 2012-10-05 -0.002305
# 2012-10-09 -0.011709

# %% [markdown]
# ## Combine Whale, Algorithmic, and S&P TSX 60 Returns

# %%
# Join Whale Returns, Algorithmic Returns, and the S&P TSX 60 Returns into a single DataFrame with columns for each portfolio's returns.
combined_portfolios_df = pd.concat([whale_returns_df,algo_returns_df, sp_tsx_returns_df], axis='columns', join='inner')
combined_portfolios_df.head()
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
# 2015-03-09                   0.000582            0.004225
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1  \
# Date
# 2015-03-03                    -0.000496               -0.006569 -0.001942
# 2015-03-04                    -0.002534                0.004213 -0.008589
# 2015-03-05                     0.002355                0.006726 -0.000955
# 2015-03-06                    -0.008481               -0.013098 -0.004957
# 2015-03-09                     0.005843               -0.001652 -0.005447
#
#               Algo 2    S&P500
# Date
# 2015-03-03 -0.000949 -0.008530
# 2015-03-04  0.002416 -0.003371
# 2015-03-05  0.004323  0.001344
# ...

# %% [markdown]
# ---

# %% [markdown]
# # Conduct Quantitative Analysis
#
# In this section, you will calculate and visualize performance and risk metrics for the portfolios.

# %% [markdown]
# ## Performance Analysis
#
# #### Calculate and Plot the daily returns.

# %%
# Plot daily returns of all portfolios
combined_portfolios_df.plot( title="Daily Returns" , figsize=(20,10))
# Out:
# <AxesSubplot:title={'center':'Daily Returns'}, xlabel='Date'>

# %% [markdown]
# #### Calculate and Plot cumulative returns.

# %%
# Calculate cumulative returns of all portfolios
combined_portfolios_df_cumulative_returns = (1 + combined_portfolios_df).cumprod()
combined_portfolios_df_cumulative_returns.head()
combined_portfolios_df_cumulative_returns.plot(figsize=(20,10))
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# ---

# %% [markdown]
# ## Risk Analysis
#
# Determine the _risk_ of each portfolio:
#
# 1. Create a box plot for each portfolio.
# 2. Calculate the standard deviation for all portfolios.
# 4. Determine which portfolios are riskier than the S&P TSX 60.
# 5. Calculate the Annualized Standard Deviation.

# %% [markdown]
# ### Create a box plot for each portfolio

# %%
# Box plot to visually show risk
combined_portfolios_df.plot.box(title= "Portfolio Risk", figsize=(20,10))
# Out:
# <AxesSubplot:title={'center':'Portfolio Risk'}>

# %% [markdown]
# ### Calculate Standard Deviations

# %%
# Calculate the daily standard deviations of all portfolios
daily_std = combined_portfolios_df.std().sort_values(ascending=False)
daily_std
# Out:
# BERKSHIRE HATHAWAY INC         0.012826
# TIGER GLOBAL MANAGEMENT LLC    0.010883
# Algo 2                         0.008326
# SOROS FUND MANAGEMENT LLC      0.007828
# Algo 1                         0.007589
# S&P500                         0.007034
# PAULSON & CO.INC.              0.006982
# dtype: float64

# %% [markdown]
# ### Determine which portfolios are riskier than the S&P TSX 60

# %%
# Calculate  the daily standard deviation of S&P TSX 60
portfolios_riskier_than_SP500 =[daily_std > daily_std['S&P500']]
# Determine which portfolios are riskier than the S&P TSX 60
portfolios_riskier_than_SP500
# Out:
# [BERKSHIRE HATHAWAY INC          True
#  TIGER GLOBAL MANAGEMENT LLC     True
#  Algo 2                          True
#  SOROS FUND MANAGEMENT LLC       True
#  Algo 1                          True
#  S&P500                         False
#  PAULSON & CO.INC.              False
#  dtype: bool]

# %% [markdown]
# ### Calculate the Annualized Standard Deviation

# %%
# Calculate the annualized standard deviation (252 trading days)
annualized_std = daily_std *np.sqrt(252)
annualized_std.sort_values(ascending=False)
# Out:
# BERKSHIRE HATHAWAY INC         0.203599
# TIGER GLOBAL MANAGEMENT LLC    0.172759
# Algo 2                         0.132177
# SOROS FUND MANAGEMENT LLC      0.124259
# Algo 1                         0.120470
# S&P500                         0.111664
# PAULSON & CO.INC.              0.110841
# dtype: float64

# %% [markdown]
# ---

# %% [markdown]
# ## Rolling Statistics
#
# Risk changes over time. Analyze the rolling statistics for Risk and Beta.
#
# 1. Calculate and plot the rolling standard deviation for all portfolios using a 21-day window.
# 2. Calculate the correlation between each stock to determine which portfolios may mimick the S&P TSX 60.
# 3. Choose one portfolio, then calculate and plot the 60-day rolling beta for it and the S&P TSX 60.

# %% [markdown]
# ### Calculate and plot rolling `std` for all portfolios with 21-day window

# %%
# Calculate the rolling standard deviation for all portfolios using a 21-day window
combined_portfolios_df.rolling(window=21).std().plot(title="21 Day Rolling Standard Deviation", figsize=(20,10))
# Plot the rolling standard deviation
# Out:
# <AxesSubplot:title={'center':'21 Day Rolling Standard Deviation'}, xlabel='Date'>

# %% [markdown]
# ### Calculate and plot the correlation

# %%
# Calculate the correlation
correlation = combined_portfolios_df.corr()
correlation
# Display de correlation matrix
#combined_portfolios_df.plot(kind="scatter", y = "Algo 2", x = "S&P500", figsize = (20,10))
# Out:
#                              SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# SOROS FUND MANAGEMENT LLC                     1.000000            0.697076
# PAULSON & CO.INC.                             0.697076            1.000000
# TIGER GLOBAL MANAGEMENT LLC                   0.560964            0.433034
# BERKSHIRE HATHAWAY INC                        0.750181            0.540033
# Algo 1                                        0.313795            0.266363
# Algo 2                                        0.826667            0.674015
# S&P500                                        0.673930            0.486511
#
#                              TIGER GLOBAL MANAGEMENT LLC  \
# SOROS FUND MANAGEMENT LLC                       0.560964
# PAULSON & CO.INC.                               0.433034
# TIGER GLOBAL MANAGEMENT LLC                     1.000000
# BERKSHIRE HATHAWAY INC                          0.423524
# Algo 1                                          0.161236
# ...

# %% [markdown]
# ### Calculate and Plot Beta for a chosen portfolio and the S&P 60 TSX

# %%
# Calculate covariance of a single portfolio
algo_2_covariance = combined_portfolios_df['Algo 2'].rolling(window=60).cov(combined_portfolios_df['S&P500'])
algo_2_covariance
# Calculate variance of S&P TSX
variance = combined_portfolios_df['S&P500'].rolling(window=60).var()

# Computing beta
algo_2_beta = algo_2_covariance / variance
# Plot beta trend
algo_2_beta.plot(title="Algo 2 Beta", figsize=(20, 10))
# Out:
# <AxesSubplot:title={'center':'Algo 2 Beta'}, xlabel='Date'>

# %% [markdown]
# ## Rolling Statistics Challenge: Exponentially Weighted Average
#
# An alternative way to calculate a rolling window is to take the exponentially weighted moving average. This is like a moving window average, but it assigns greater importance to more recent observations. Try calculating the [`ewm`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.ewm.html) with a 21-day half-life.

# %%
# Use `ewm` to calculate the rolling window
#rolling_window_ewma = combined_portfolios_df.rolling(window=100).mean().plot(figsize=(20, 10))
rolling_window_ewma = combined_portfolios_df.ewm(halflife=21, adjust=True).std().plot(title="Exponentialy Weighted Average", figsize=(20, 10))
rolling_window_ewma
# Out:
# <AxesSubplot:title={'center':'Exponentialy Weighted Average'}, xlabel='Date'>

# %% [markdown]
# ---

# %% [markdown]
# # Sharpe Ratios
# In reality, investment managers and thier institutional investors look at the ratio of return-to-risk, and not just returns alone. After all, if you could invest in one of two portfolios, and each offered the same 10% return, yet one offered lower risk, you'd take that one, right?
#
# ### Using the daily returns, calculate and visualize the Sharpe ratios using a bar plot

# %%
# Annualized Sharpe Ratios
sharpe_ratios = (combined_portfolios_df.mean() * 252) / (combined_portfolios_df.std() * np.sqrt(252))
sharpe_ratios
# Out:
# SOROS FUND MANAGEMENT LLC      0.286709
# PAULSON & CO.INC.             -0.547594
# TIGER GLOBAL MANAGEMENT LLC   -0.144455
# BERKSHIRE HATHAWAY INC         0.467045
# Algo 1                         1.491514
# Algo 2                         0.396817
# S&P500                         0.195550
# dtype: float64

# %%
# Visualize the sharpe ratios as a bar plot
sharpe_ratios.plot(figsize=(10,5), kind="bar", title="Sharpe Ratios")
# Out:
# <AxesSubplot:title={'center':'Sharpe Ratios'}>

# %% [markdown]
# ### Determine whether the algorithmic strategies outperform both the market (S&P TSX 60) and the whales portfolios.
# In summary Algo 1 outperformed the S&P TSX 60 and all the whales's portfolios.
# Although we need to take into consideration Algo 2 performed better than most of the other porfolios although under performed marginally to Berkshire Hathaway Inc. portfolio.
# If we reference the Rolling average graph and Sharp's ratio graph we can visually see how Algorithmic stratergies outperformed S&P TSX 60 and all the whales's portfolio.
# In summary overall the Algorithmic stratergies outperformed both S&P TSX 60 and Whales Portfolio

# %% [markdown]
# ---

# %% [markdown]
# # Create Custom Portfolio
#
# In this section, you will build your own portfolio of stocks, calculate the returns, and compare the results to the Whale Portfolios and the S&P TSX 60.
#
# 1. Choose 3-5 custom stocks with at last 1 year's worth of historic prices and create a DataFrame of the closing prices and dates for each stock.
# 2. Calculate the weighted returns for the portfolio assuming an equal number of shares for each stock.
# 3. Join your portfolio returns to the DataFrame that contains all of the portfolio returns.
# 4. Re-run the performance and risk analysis with your portfolio to see how it compares to the others.
# 5. Include correlation analysis to determine which stocks (if any) are correlated.

# %% [markdown]
# ## Choose 3-5 custom stocks with at last 1 year's worth of historic prices and create a DataFrame of the closing prices and dates for each stock.
#
# For this demo solution, we fetch data from three companies listes in the S&P TSX 60 index.
#
# * `SHOP` - [Shopify Inc](https://en.wikipedia.org/wiki/Shopify)
#
# * `OTEX` - [Open Text Corporation](https://en.wikipedia.org/wiki/OpenText)
#
# * `L` - [Loblaw Companies Limited](https://en.wikipedia.org/wiki/Loblaw_Companies)

# %%
# Reading data from 1st stock
shopify_csv = Path("shop_historical.csv")
shopify_df = pd.read_csv(shopify_csv)
shopify_df  = pd.read_csv(shopify_csv, index_col="Date", parse_dates=True, infer_datetime_format=True)
shopify_df.drop(columns=['Symbol'],inplace=True)
shopify_df.head(10)
# Out:
#              Close
# Date
# 2018-01-02  132.06
# 2018-01-03  135.15
# 2018-01-04  137.46
# 2018-01-05  137.26
# 2018-01-08  139.51
# 2018-01-09  137.94
# 2018-01-10  139.29
# 2018-01-11  139.14
# 2018-01-12  140.76
# 2018-01-15  142.80

# %%
# Count nulls
shopify_df.isnull().sum()
# Out:
# Close    0
# dtype: int64

# %%
# Reading data from 2nd stock
historical_csv = Path("historical.csv")
historical_df =  pd.read_csv(historical_csv, index_col="Date", parse_dates=True, infer_datetime_format=True)
historical_df.drop(columns=['Symbol'],inplace=True)
historical_df.head(10)
# Out:
#             Close
# Date
# 2018-01-02  57.99
# 2018-01-03  57.41
# 2018-01-04  57.42
# 2018-01-05  57.42
# 2018-01-08  56.86
# 2018-01-09  57.37
# 2018-01-10  57.09
# 2018-01-11  56.78
# 2018-01-12  56.97
# 2018-01-15  57.38

# %%
# Count nulls
historical_df.isnull().sum()
# Out:
# Close    0
# dtype: int64

# %%
# Reading data from 3rd stock
otex_historical_csv = Path("otex_historical.csv")
otex_historical_df =  pd.read_csv(otex_historical_csv, index_col="Date", parse_dates=True, infer_datetime_format=True)
otex_historical_df.drop(columns=['Symbol'],inplace=True)
otex_historical_df.head(10)
# Out:
#             Close
# Date
# 2018-01-02  43.58
# 2018-01-03  43.07
# 2018-01-04  42.91
# 2018-01-05  42.57
# 2018-01-08  42.16
# 2018-01-09  42.13
# 2018-01-10  41.99
# 2018-01-11  42.29
# 2018-01-12  42.17
# 2018-01-15  41.79

# %%
# Count nulls
otex_historical_df.isnull().sum()
# Out:
# Close    0
# dtype: int64

# %%
# Combine all stocks in a single DataFrame
my_portfolio_combined_df = pd.concat([otex_historical_df, historical_df, shopify_df], axis="columns", join="inner")
my_portfolio_combined_df
# Sort datetime index in ascending order (past to present)
my_portfolio_combined_df.sort_values("Date", ascending=True)
my_portfolio_combined_df.head()
# Set column names
# Out:
#             Close  Close   Close
# Date
# 2018-01-02  43.58  57.99  132.06
# 2018-01-03  43.07  57.41  135.15
# 2018-01-04  42.91  57.42  137.46
# 2018-01-05  42.57  57.42  137.26
# 2018-01-08  42.16  56.86  139.51

# %%
# Reorganize portfolio data by having a column per symbol
my_portfolio_combined_df.columns = ['Shopify', 'Hist', 'Otex']
my_portfolio_combined_df.head()
# Out:
#             Shopify   Hist    Otex
# Date
# 2018-01-02    43.58  57.99  132.06
# 2018-01-03    43.07  57.41  135.15
# 2018-01-04    42.91  57.42  137.46
# 2018-01-05    42.57  57.42  137.26
# 2018-01-08    42.16  56.86  139.51

# %%
# Reset Date index
my_portfolio_combined_df.reset_index()
# Out:
#           Date  Shopify   Hist    Otex
# 0   2018-01-02    43.58  57.99  132.06
# 1   2018-01-03    43.07  57.41  135.15
# 2   2018-01-04    42.91  57.42  137.46
# 3   2018-01-05    42.57  57.42  137.26
# 4   2018-01-08    42.16  56.86  139.51
# ..         ...      ...    ...     ...
# 496 2019-12-20    58.68  67.90  513.22
# 497 2019-12-23    57.89  67.68  511.62
# 498 2019-12-24    57.44  67.67  525.39
# 499 2019-12-27    57.70  67.78  534.76
# 500 2019-12-30    57.19  67.33  517.79
#
# [501 rows x 4 columns]

# %%
my_portfolio_combined_df.dropna()
my_portfolio_combined_df.head(10)
# Out:
#             Shopify   Hist    Otex
# Date
# 2018-01-02    43.58  57.99  132.06
# 2018-01-03    43.07  57.41  135.15
# 2018-01-04    42.91  57.42  137.46
# 2018-01-05    42.57  57.42  137.26
# 2018-01-08    42.16  56.86  139.51
# 2018-01-09    42.13  57.37  137.94
# 2018-01-10    41.99  57.09  139.29
# 2018-01-11    42.29  56.78  139.14
# 2018-01-12    42.17  56.97  140.76
# 2018-01-15    41.79  57.38  142.80

# %%
# Calculate daily returns
my_portfolio_combined_df = my_portfolio_combined_df.pct_change()
my_portfolio_combined_df.dropna(inplace=True)
my_portfolio_combined_df.head()
# Drop NAs
# Display sample data
my_portfolio_combined_df.head()
# Out:
#              Shopify      Hist      Otex
# Date
# 2018-01-03 -0.011703 -0.010002  0.023398
# 2018-01-04 -0.003715  0.000174  0.017092
# 2018-01-05 -0.007924  0.000000 -0.001455
# 2018-01-08 -0.009631 -0.009753  0.016392
# 2018-01-09 -0.000712  0.008969 -0.011254

# %% [markdown]
# ## Calculate the weighted returns for the portfolio assuming an equal number of shares for each stock

# %%
# Set weights
weights = [1/3, 1/3, 1/3]

# Calculate portfolio return
my_portfolio_weighted_df = my_portfolio_combined_df.dot(weights)
# Display sample data
my_portfolio_weighted_df.head(10)
# Out:
# Date
# 2018-01-03    0.000565
# 2018-01-04    0.004517
# 2018-01-05   -0.003126
# 2018-01-08   -0.000997
# 2018-01-09   -0.000999
# 2018-01-10    0.000528
# 2018-01-11    0.000213
# 2018-01-12    0.004051
# 2018-01-15    0.004226
# 2018-01-16   -0.008559
# dtype: float64

# %%
my_portfolio_weighted_df = my_portfolio_weighted_df.rename("My_Portfolio")
my_portfolio_weighted_df.head(10)
# Out:
# Date
# 2018-01-03    0.000565
# 2018-01-04    0.004517
# 2018-01-05   -0.003126
# 2018-01-08   -0.000997
# 2018-01-09   -0.000999
# 2018-01-10    0.000528
# 2018-01-11    0.000213
# 2018-01-12    0.004051
# 2018-01-15    0.004226
# 2018-01-16   -0.008559
# Name: My_Portfolio, dtype: float64

# %% [markdown]
# ## Join your portfolio returns to the DataFrame that contains all of the portfolio returns

# %%
# Join your returns DataFrame to the original returns DataFrame
combined_portfolios_2_df = pd.concat([my_portfolio_weighted_df,whale_returns_df,algo_returns_df, sp_tsx_returns_df,], axis='columns', join='inner')
combined_portfolios_2_df
# Out:
#             My_Portfolio  SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2018-01-03      0.000565                   0.004658            0.000027
# 2018-01-04      0.004517                  -0.000914            0.004196
# 2018-01-05     -0.003126                   0.004072            0.000823
# 2018-01-08     -0.000997                   0.004473           -0.003739
# 2018-01-09     -0.000999                  -0.001028            0.000872
# ...                  ...                        ...                 ...
# 2019-04-25      0.003461                  -0.000285           -0.001291
# 2019-04-26      0.003243                   0.008149            0.009162
# 2019-04-29      0.003303                   0.001254            0.002719
# 2019-04-30      0.026937                  -0.001295           -0.002211
# 2019-05-01     -0.000079                  -0.005847           -0.001341
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1  \
# Date
# ...

# %%
# Only compare dates where return data exists for all the stocks (drop NaNs)
combined_portfolios_2_df.dropna(inplace = True)
combined_portfolios_2_df
# Out:
#             My_Portfolio  SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2018-01-03      0.000565                   0.004658            0.000027
# 2018-01-04      0.004517                  -0.000914            0.004196
# 2018-01-05     -0.003126                   0.004072            0.000823
# 2018-01-08     -0.000997                   0.004473           -0.003739
# 2018-01-09     -0.000999                  -0.001028            0.000872
# ...                  ...                        ...                 ...
# 2019-04-25      0.003461                  -0.000285           -0.001291
# 2019-04-26      0.003243                   0.008149            0.009162
# 2019-04-29      0.003303                   0.001254            0.002719
# 2019-04-30      0.026937                  -0.001295           -0.002211
# 2019-05-01     -0.000079                  -0.005847           -0.001341
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1  \
# Date
# ...

# %% [markdown]
# ## Re-run the risk analysis with your portfolio to see how it compares to the others

# %% [markdown]
# ### Calculate the Annualized Standard Deviation

# %%
# Calculate the annualized `std`
annualized_combined_std = combined_portfolios_2_df *np.sqrt(252)
annualized_combined_std.std().sort_values(ascending=False)
annualized_combined_std
# Out:
#             My_Portfolio  SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2018-01-03      0.008964                   0.073936            0.000430
# 2018-01-04      0.071707                  -0.014515            0.066617
# 2018-01-05     -0.049627                   0.064634            0.013069
# 2018-01-08     -0.015830                   0.071000           -0.059350
# 2018-01-09     -0.015853                  -0.016311            0.013847
# ...                  ...                        ...                 ...
# 2019-04-25      0.054942                  -0.004522           -0.020491
# 2019-04-26      0.051484                   0.129369            0.145437
# 2019-04-29      0.052435                   0.019912            0.043165
# 2019-04-30      0.427618                  -0.020550           -0.035106
# 2019-05-01     -0.001259                  -0.092819           -0.021291
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1  \
# Date
# ...

# %% [markdown]
# ### Calculate and plot rolling `std` with 21-day window

# %%
# Calculate rolling standard deviation
combined_portfolios_2_df.rolling(window=21).std().plot(title="21 Day Rolling Standard Deviation", figsize=(20,10))
# Out:
# <AxesSubplot:title={'center':'21 Day Rolling Standard Deviation'}, xlabel='Date'>

# %% [markdown]
# ### Calculate and plot the correlation

# %%
# Calculate and plot the correlation
combined_portfolios_2_df_cumulative_returns = (1 + combined_portfolios_2_df).cumprod()
combined_portfolios_2_df_cumulative_returns.head()
combined_portfolios_2_df_cumulative_returns.plot(figsize=(20,10))
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# ### Calculate and Plot the 60-day Rolling Beta for Your Portfolio compared to the S&P 60 TSX

# %%
# Calculate and plot Beta
rolling_covariance = combined_portfolios_2_df["My_Portfolio"].rolling(window=60).cov(combined_portfolios_2_df["S&P500"])
rolling_variance = combined_portfolios_2_df["S&P500"].rolling(window=60).var()
rolling_beta = rolling_covariance / rolling_variance
rolling_beta.plot(figsize=(20, 10), title='Rolling 60-Day Beta of my portfolio')
# Out:
# <AxesSubplot:title={'center':'Rolling 60-Day Beta of my portfolio'}, xlabel='Date'>

# %% [markdown]
# ### Using the daily returns, calculate and visualize the Sharpe ratios using a bar plot

# %%
# Calculate Annualzied Sharpe Ratios
combined_portfolios_2_df_sharpe_ratios = (combined_portfolios_2_df.mean() * 252) / (combined_portfolios_2_df.std() * np.sqrt(252))
combined_portfolios_2_df_sharpe_ratios.sort_values(ascending=False)
# Out:
# Algo 1                         1.901461
# My_Portfolio                   1.564547
# BERKSHIRE HATHAWAY INC         0.195907
# S&P500                         0.034651
# Algo 2                         0.021394
# SOROS FUND MANAGEMENT LLC     -0.088196
# PAULSON & CO.INC.             -0.396282
# TIGER GLOBAL MANAGEMENT LLC   -1.391612
# dtype: float64

# %%
# Visualize the sharpe ratios as a bar plot
combined_portfolios_2_df_sharpe_ratios.plot(figsize=(10,5), kind="bar",title="Sharpe Ratios")
combined_portfolios_2_df_sharpe_ratios.plot(kind="bar", title="Sharpe Ratios")
# Out:
# <AxesSubplot:title={'center':'Sharpe Ratios'}>

# %% [markdown]
# ### How does your portfolio do?
#
# Interpretation of the graphs overall on average My Portfolio has the highest annualized standard deviation of all the portfolios being analyzed when reviewing the numerical data.
# The best repesentation is we can see visually in the 21 day rolling standard deviation plot.
# If we compare sharpe ratio Algo_1 porfolio is the highest followed by My Portfolio.
# We can see that our custom porfolio is closest correlated to Algo_1 portfolio.
# In comparison Tiger Global, Soros Fund and Paulson and Co showing a negative correlation.
# In addition looking at the coorelation in cumulative returns My portfolio performed the best and better than Algo 1.
# In summary this indicates that we were able to accomplish the task of choosing a portfolio  that performed better than the Portfolio choosen by ones chosen by Harold.
